# %% [markdown]
# # This notebook demonstrates the way to use the catalog that is created by Data Discovery Tool, for the data produced by the downstream applications of the destination Earth Twin engine, at differnt HPC centers and using differnt ESMs.

# %%
import intake

# %% [markdown]
# # Open the master catalog and create a catalog object which can be queried to load the contents needed by user analytical tasks.

# %%
outputPath=".."
masterCatalog = intake.open_catalog(f"{outputPath}/output/intakeCatalog/datadiscovererIntakeCatalog.yaml")

# %% [markdown]
# # List the contents

# %%
list(masterCatalog)
# Out:
# ['LUMI', 'MareNostrum']

# %% [markdown]
# # Programmatic usage of the catalog with the GUI.

# %%
from IPython.display import Image, display

# %%
display(Image(masterCatalog.LUMI.AQUA.ICON.image.image1.urlpath))

# %%
from IPython.display import IFrame
print(masterCatalog.LUMI.AQUA.ICON.image.image1.urlpath)
# Out:
# /work/bm0146/k204247/DestinE/destinE_DDTool/destinEData/AQUA/P3.jpg

# %%
IFrame(masterCatalog.LUMI.AQUA.ICON.image.image1.urlpath, width=600, height=300)

# %%
from wand.image import Image as WImage
img = WImage(filename=masterCatalog.LUMI.AQUA.ICON.image.image1.urlpath,resolution=100)
img
# Out:
# <wand.image.Image: 66cce98 'JPEG' (605x501)>

# %%
from IPython.display import display_pdf
with open(masterCatalog.LUMI.AQUA.ICON.image.image10.urlpath, "rb") as f:
    display_pdf(f.read(),raw=True)

# %%
print(masterCatalog.LUMI.AQUA.ICON.image.image1.urlpath)
# Out:
# /work/bm0146/k204247/DestinE/destinE_DDTool/destinEData/AQUA/P3.jpg

# %%
filename="/work/bm0146/k204247/DestinE/destinE_DDTool/destinEData/AQUA/trop_rainfall__histogram.pdf"
from IPython.display import display_pdf
with open(filename, "rb") as f:
    display_pdf(f.read(),raw=True)
