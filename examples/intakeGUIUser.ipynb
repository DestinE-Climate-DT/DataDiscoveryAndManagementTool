# %% [markdown]
# # This notebook demonstrates the way to use the catalog that is created by Data Discovery Tool, for the data produced by the downstream applications of the destination Earth Twin engine, at differnt HPC centers and using differnt ESMs.

# %%
import intake

# %% [markdown]
# # Open the master catalog and create a catalog object which can be queried to load the contents needed by user analytical tasks.

# %%
outputPath=".."
masterCatalog = intake.open_catalog(f"{outputPath}/output/intakeCatalog/datadiscovererIntakeCatalog.yaml")

# %% [markdown]
# # List the contents

# %%
list(masterCatalog)

# %% [markdown]
# # Interactive usage of the catalog with the GUI.

# %%
import panel
import bokeh

# %%
panel.extension()
intake.interface.gui.GUI(f"{outputPath}/output/intakeCatalog/datadiscovererIntakeCatalog.yaml")
# Out:
# WARNING:param.panel_extension: A HoloViz extension was loaded previously. This means the extension is already initialized and custom raw_css resources could not be loaded. If you are loading custom extensions with pn.extension(...) ensure that this is calledbefore any other HoloViz extension such as hvPlot or HoloViews.
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# Column(width_policy='max')
#     [0] Row(width_policy='max')
#         [0] PNG(str)
#         [1] Column(width_policy='max')
#             [0] Column(name='Select Catalog')
#                 [0] Markdown(str, max_height=40)
#                 [1] MultiSelect(min_width=200, options={'datadiscovererIntakeCata...}, size=9, value=[<Intake catalog: d...], width_policy='min')
#             [1] Row(name='Controls')
#                 [0] Toggle(name='＋', width=50)
# ...

# %%
from IPython.display import Image, display
print(masterCatalog.LUMI.AQUA.IFS.image.image33)

# %%
from IPython.display import IFrame
print(masterCatalog.LUMI.AQUA.IFS.image.image1.urlpath)

# %%
IFrame(masterCatalog.LUMI.AQUA.IFS.image.image1.urlpath, width=600, height=300)

# %%
display(Image(masterCatalog.LUMI.AQUA.IFS.image.image1.urlpath))

# %%
from wand.image import Image as WImage
img = WImage(filename=masterCatalog.LUMI.AQUA.IFS.image.image1.urlpath,resolution=100)
img

# %%
from IPython.display import display_pdf
with open(masterCatalog.LUMI.AQUA.IFS.image.image10.urlpath, "rb") as f:
    display_pdf(f.read(),raw=True)

# %%
print(masterCatalog.LUMI.AQUA.IFS.image.image1.urlpath)

# %%
filename="../destinEData/AQUA/trop_rainfall__histogram.pdf"
from IPython.display import display_pdf
with open(filename, "rb") as f:
    display_pdf(f.read(),raw=True)
