# %% [markdown]
# # This notebook demonstrates the way to curate the data, that is being produced by the applications from the GSV generated by the destination Earth Twin engine, into an intake catalog.

# %%
import intake
import os
import sys
import json
sys.path.insert(0,"/work/bm0146/k204247/DestinE/destinE_DDTool")
import datadiscoverer

# %% [markdown]
# # Create a mapping of the data source names ( file types ) and the APIs to update them into the catalog.

# %%
curconfig = datadiscoverer.configDatadiscoverer()
catalogPath="/work/bm0146/k204247/DestinE/destinE_DDTool/output/intakeCatalog"
with open("/work/bm0146/k204247/DestinE/destinE_DDTool/datadiscoverer/datadiscovererConfig.json") as f:
    userConfig = json.load(f)
    curconfig.setConfigfromJSON(userConfig)
datadiscoverer.configDatadiscoverer.activeConfig=curconfig

# %%
curconfig.setdatadiscovererOutputPath(catalogPath)
datadiscoverer.createAppDataSrcNamesIntakeAPImap()
curconfig.getdatadiscovererOutputPath()
datadiscoverer.configDatadiscoverer.activeConfig.getappDataSrcNamesAPImap()
# Out:
# ...
# {'hpcCenters': ['LUMI', 'MareNostrum'], 'esmNames': ['ICON', 'IFS'], 'appDataSrcNames': ['netcdf', 'image', 'text'], 'appDataSrcNameFileExt': {'netcdf': ['*.nc'], 'image': ['*.jpg', '*.pdf', '*.png', '*.gif'], 'text': ['*.txt', '*.csv']}, 'datadiscovererDataPath': '/work/bm0146/k204247/DestinE/destinE_DDTool/destinEData', 'datadiscovererOutputPath': '/work/bm0146/k204247/DestinE/destinE_DDTool/output', 'appDataSrcNamesAPImap': {}, 'ddtBasePath': '/work/bm0146/k204247/DestinE/destinE_DDTool', 'appNamesList': ['AQUA', 'EnergyOnShore', 'EnergyOffShore', 'FWI', 'HydroMet', 'HydroRiver', 'SPITFIRE', 'Urban', 'WISE'], 'appDataSrcFlags': {'AQUA': [True, True, False], 'EnergyOnShore': [True, True, True], 'EnergyOffShore': [True, True, False], 'FWI': [True, True, False], 'HydroMet': [True, False, True], 'HydroRiver': [True, False, True], 'SPITFIRE': [True, False, False], 'Urban': [True, True, True], 'WISE': [False, True, False]}}
# ['netcdf', 'image', 'text']
# ...

# %% [markdown]
# # Create a master catalog layout containing the individual catalogs for each of the HPC centers, applications, models and so on.

# %%
datadiscoverer.createDDTMasterIntakeCatalog()
# Out:
# output: /work/bm0146/k204247/DestinE/destinE_DDTool/output

# %% [markdown]
# # Create the HPC catalogs.

# %%
datadiscoverer.createHPCIntakeCatalog()
# Out:
# output: /work/bm0146/k204247/DestinE/destinE_DDTool/output

# %% [markdown]
# # Update the catalogs for the individual applications.

# %%
datadiscoverer.createAppIntakeCatalog()
# Out:
# output: /work/bm0146/k204247/DestinE/destinE_DDTool/output

# %% [markdown]
# # Update the catalogs for the individual ESMs.

# %%
datadiscoverer.createESMIntakeCatalog()
# Out:
# output: /work/bm0146/k204247/DestinE/destinE_DDTool/output

# %% [markdown]
# # Update the catalogs for the individual sources.

# %%
datadiscoverer.createSrcIntakeCatalog()
# Out:
# output: /work/bm0146/k204247/DestinE/destinE_DDTool/output
# current HPC : LUMI App: AQUA ESM : ICON  Source : netcdf Flag: True
# output: /work/bm0146/k204247/DestinE/destinE_DDTool/destinEData
# /work/bm0146/k204247/DestinE/destinE_DDTool/destinEData/AQUA netcdf *.nc
# /work/bm0146/k204247/DestinE/destinE_DDTool/destinEData/AQUA/*.nc
# ['/work/bm0146/k204247/DestinE/destinE_DDTool/destinEData/AQUA/wildfire_fires_2020_2025.nc']
# current HPC : LUMI App: AQUA ESM : ICON  Source : image Flag: True
# output: /work/bm0146/k204247/DestinE/destinE_DDTool/destinEData
# /work/bm0146/k204247/DestinE/destinE_DDTool/destinEData/AQUA image *.jpg
# /work/bm0146/k204247/DestinE/destinE_DDTool/destinEData/AQUA/*.jpg
# /work/bm0146/k204247/DestinE/destinE_DDTool/destinEData/AQUA image *.pdf
# /work/bm0146/k204247/DestinE/destinE_DDTool/destinEData/AQUA/*.pdf
# /work/bm0146/k204247/DestinE/destinE_DDTool/destinEData/AQUA image *.png
# ...
