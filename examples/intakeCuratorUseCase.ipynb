# %% [markdown]
# # This notebook demonstrates the way to curate the data, that is being produced by the applications from the GSV generated by the destination Earth Twin engine, into an intake catalog.

# %%
import os
import sys
import json
sys.path.insert(0,"/work/bm0146/k204247/DestinE/destinE_DDTool")
import datadiscoverer

# %% [markdown]
# # Create a mapping of the data source names ( file types ) and the APIs to update them into the catalog.

# %%
configFile = "/work/bm0146/k204247/DestinE/destinE_DDTool/datadiscoverer/datadiscovererConfig.json"
curconfig = datadiscoverer.initializeDataDiscoverer(configFile)
catalogPath="/work/bm0146/k204247/DestinE/destinE_DDTool/output/intakeCatalog"
#print(vars(curconfig))
curconfig.setOutputPath(catalogPath)
curconfig.getOutputPath()
# Out:
# '/work/bm0146/k204247/DestinE/destinE_DDTool/output/intakeCatalog'

# %% [markdown]
# # Create a master catalog layout containing the individual catalogs for each of the HPC centers, applications, models and so on.

# %%
datadiscoverer.createDDTMasterIntakeCatalog()

# %% [markdown]
# # Create the HPC catalogs.

# %%
datadiscoverer.createHPCIntakeCatalog()

# %% [markdown]
# # Update the catalogs for the individual applications.

# %%
datadiscoverer.createAppIntakeCatalog()

# %% [markdown]
# # Update the catalogs for the individual ESMs.

# %%
datadiscoverer.createESMIntakeCatalog()

# %% [markdown]
# # Update the catalogs for the individual sources.

# %%
datadiscoverer.createSrcIntakeCatalog()
# Out:
# Ingesting 'AQUA' data produced using GSV from ICON simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/AQUA netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/AQUA image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# Ingesting 'AQUA' data produced using GSV from IFS simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/AQUA netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/AQUA image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# Ingesting 'EnergyOnShore' data produced using GSV from ICON simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOnShore netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOnShore image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOnShore text
# 		*.txt
# 		*.csv
# Ingesting 'EnergyOnShore' data produced using GSV from IFS simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOnShore netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOnShore image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOnShore text
# 		*.txt
# 		*.csv
# Ingesting 'EnergyOffShore' data produced using GSV from ICON simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOffShore netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOffShore image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# Ingesting 'EnergyOffShore' data produced using GSV from IFS simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOffShore netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOffShore image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# Ingesting 'FWI' data produced using GSV from ICON simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/FWI netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/FWI image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# Ingesting 'FWI' data produced using GSV from IFS simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/FWI netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/FWI image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# Ingesting 'HydroMet' data produced using GSV from ICON simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroMet netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroMet text
# 		*.txt
# 		*.csv
# Ingesting 'HydroMet' data produced using GSV from IFS simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroMet netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroMet text
# 		*.txt
# 		*.csv
# Ingesting 'HydroRiver' data produced using GSV from ICON simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroRiver netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroRiver text
# 		*.txt
# 		*.csv
# Ingesting 'HydroRiver' data produced using GSV from IFS simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroRiver netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroRiver text
# 		*.txt
# 		*.csv
# Ingesting 'SPITFIRE' data produced using GSV from ICON simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/SPITFIRE netcdf
# 		*.nc
# Ingesting 'SPITFIRE' data produced using GSV from IFS simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/SPITFIRE netcdf
# 		*.nc
# Ingesting 'Urban' data produced using GSV from ICON simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/Urban netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/Urban image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/Urban text
# 		*.txt
# 		*.csv
# Ingesting 'Urban' data produced using GSV from IFS simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/Urban netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/Urban image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/Urban text
# 		*.txt
# 		*.csv
# Ingesting 'WISE' data produced using GSV from ICON simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/WISE image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# Ingesting 'WISE' data produced using GSV from IFS simulations performed on LUMI
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/WISE image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# Ingesting 'AQUA' data produced using GSV from ICON simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/AQUA netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/AQUA image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# Ingesting 'AQUA' data produced using GSV from IFS simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/AQUA netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/AQUA image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# Ingesting 'EnergyOnShore' data produced using GSV from ICON simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOnShore netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOnShore image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOnShore text
# 		*.txt
# 		*.csv
# Ingesting 'EnergyOnShore' data produced using GSV from IFS simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOnShore netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOnShore image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOnShore text
# 		*.txt
# 		*.csv
# Ingesting 'EnergyOffShore' data produced using GSV from ICON simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOffShore netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOffShore image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# Ingesting 'EnergyOffShore' data produced using GSV from IFS simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOffShore netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/EnergyOffShore image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# Ingesting 'FWI' data produced using GSV from ICON simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/FWI netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/FWI image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# Ingesting 'FWI' data produced using GSV from IFS simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/FWI netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/FWI image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# Ingesting 'HydroMet' data produced using GSV from ICON simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroMet netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroMet text
# 		*.txt
# 		*.csv
# Ingesting 'HydroMet' data produced using GSV from IFS simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroMet netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroMet text
# 		*.txt
# 		*.csv
# Ingesting 'HydroRiver' data produced using GSV from ICON simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroRiver netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroRiver text
# 		*.txt
# 		*.csv
# Ingesting 'HydroRiver' data produced using GSV from IFS simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroRiver netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/HydroRiver text
# 		*.txt
# 		*.csv
# Ingesting 'SPITFIRE' data produced using GSV from ICON simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/SPITFIRE netcdf
# 		*.nc
# Ingesting 'SPITFIRE' data produced using GSV from IFS simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/SPITFIRE netcdf
# 		*.nc
# Ingesting 'Urban' data produced using GSV from ICON simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/Urban netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/Urban image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/Urban text
# 		*.txt
# 		*.csv
# Ingesting 'Urban' data produced using GSV from IFS simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/Urban netcdf
# 		*.nc
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/Urban image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/Urban text
# 		*.txt
# 		*.csv
# Ingesting 'WISE' data produced using GSV from ICON simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/WISE image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
# Ingesting 'WISE' data produced using GSV from IFS simulations performed on MareNostrum
# 	/work/bm0146/k204247/DestinE/destinE_DDTool/destinE_AppData/WISE image
# 		*.jpg
# 		*.pdf
# 		*.png
# 		*.gif
